# %% [markdown]
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />
# <br><br><br>
# <h1>Game Assignment Code</h1>
# <h4>Python for Data Analysts: Methods & Tools - DAT-7466 - FMBANDD</h4>
# Written by Ayane Horinouchi
# <br>
# <br>
# <br>
# <br>
# STORY:
# <br>
# Momotaro is an old Japanese fairy tale. Momotaro, the hero, is born from a
# peach and goes to exterminate ogres with dog, monkey, and bird. Momotaro
# and his friends fought the ogres and won the battle.
# <br>
# <br>
# DIRECTIONS:
# <br>
# In this game, you need to answer questions to help Momotaro. The questions are both descriptive and multiple choices style.
# Please read the instruction for each question carefully.
# <br>
# <br>
# SOURCE:
# <br>
# About the explanation of Dango, room2
# <br>
# Dango-yamaka. (2022, January 26). What Are the Particular Points of Dumplings? And the Types of Dumplings!(in Japanese) Dango-Yamaka. Retrieved January 22, 2023, from https://www.dango-yamaka.jp/blog/3277/
# <br>
# <br>
# About the explanation of Manju, room2
# <br>
# Enakawakamiya. (2020, September 2). What Is the History of Manju? A Detailed Look at Its Origin, Origins, and More! Enakawakamiya. Retrieved January 22, 2023, from https://column.enakawakamiya.co.jp/japanese/manju-history.html
# <br>
# <br>
# About the explanation of momo, room1
# <br>
# Ministry of agriculture, forestry and fisheries. (2019, May). History and Main Varieties of Peach (in Japanese). Ministry of Agriculture, Forestry and Fisheries. Retrieved January 22, 2023, from https://www.maff.go.jp/j/pr/aff/1905_06/spe2_01.html
# <br>
# <br>
# About the explanation of Yokan, room2
# <br>
# Kaiundo. (2019, January 28). The History of Yokan. Kaiundo. Retrieved January 22, 2023, from https://www.kaiundo.co.jp/blog/blog/%E7%BE%8A%E7%BE%B9%E3%81%AE%E6%AD%B4%E5%8F%B2%E3%81%AB%E3%81%A4%E3%81%84%E3%81%A6.php
# <br>
# <br>
# About the book:
# <br>
# Kusuyama, M. (1983, May 10). Momotaro(in Japanese). Aozorabunko. Retrieved January 22, 2023, from https://www.aozora.gr.jp/cards/000329/card18376.html
# <br>
# <br>
# <br>
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />

# %%
#########################################################
# Stage ０: Meeting with Peach
#########################################################
from art import *

def room_0():
    
    #Printing introduction information 
    print(f"""
    {'-' * 75}
     STORY
     Momotaro is an old Japanese fairy tale. Momotaro, the hero, is born from 
     a peach and goes to exterminate ogres. Will he be able to exterminate the
     ogres and bring peace to his village?\n
     
     DIRECTIONS
     In this game, you are going to answer some quizzes to help "Momotaro".
     Please read the instruction for each question carefully.
    {'-' * 75}
     START
     Once upon a time, there was an old man and an old woman.
     The grandfather went to the mountains to cut bush bushes, and the 
     grandmother went to the river to wash clothes.While the grandmother 
     was washing her clothes in the river, a big peach came floating down 
     from upstream.
    {'-' * 75}\n""")
    
    # start a game
    start = input(prompt = """
    Do you wanna pick the peach? y/n
    """)
    
    # displaying the correct answer and explanation  using nested conditions
    if 'y' in start.lower():
        print("""Welcome!The game has been started.\n""")
    elif 'n' in start.lower():
        print("""Ok, why are you so mean? Anyway you have to start this game.""")
    else:
        print("""Invalid entry""")
    
    input(prompt = """press < ENTER > to go to room_1.\n""")
    
    # This moves us into room_1
    room_1()

#########################################################
# Stage 1: Momotaro's birth
#########################################################

def room_1():
    
    #Printing introduction information 
    print(f"""
    {'-' * 75}
    You're in room_1!\n
    The old woman brought the peach home.When she broke the peach open to 
    eat it, a healthy boy jumped out from inside.The grandfather and 
    grandmother, who had no children, were very happy and named the boy 
    Momotaro, and raised him with great care.
    {'-' * 75}\n""")
    
    #Asking the user's input
    input(prompt = """press < ENTER > to continue.\n""")
    
    quiz_1 = input(prompt = """
    What is a word for peach in Japanese?\n
    **You can try this quiz until twice.\n
    **Please type your answer in alphabet in lower case, 
    not in hiragana or kanji.
          """)
    
    #Conditional statement: show the different message depending on right or wrong answer
    if 'momo' in quiz_1.lower():
        print("""
        That's right.\n
        Momo, peach in English, is one of the very popular fruits in Japan. 
        It is believed that peaches were introduced from China in ancient 
        times. In China, there is a legend that a hermit who ate a peach 
        became immortal, and it has been believed that the flowers, leaves, 
        and branches also have the effect of repelling evil spirits. In 
        Japan, peaches are said to scare away demons, leading to the old 
        tale "Momotarou".
        """)
            
    elif 'momo' not in quiz_1.lower():
        print("""
        Good try, but your answer is not correct.\n
        The answer was "momo".\n
        Momo, peach in English, is one of the very popular fruits in Japan. 
        It is believed that peaches were introduced from China in ancient 
        times. In China, there is a legend that a hermit who ate a peach 
        became immortal, and it has been believed that the flowers, leaves, 
        and branches also have the effect of repelling evil spirits. In 
        Japan, peaches are said to scare away demons, leading to the old 
        tale "Momotarou".
        """)    

    else:
        print("""Error.""")
            
    input(prompt = """press < ENTER > to go to room_2.\n""")
    
    # This moves us into room_2 
    room_2() 
            
#########################################################
# Stage 2: Momotaro's departure
#########################################################

def room_2():
    
    #Printing introduction information
    print(f"""
    {'-' * 75}
    You're in room_2!\n
    Momotaro is now 15 years old. Momotaro was stronger than anyone else and
    wanted to test his skills. At that time, he heard that there was an island
    called Onigashima, far off in the sea, where wicked ogres were lining 
    their pockets with the treasures they had stolen, and he decided to go 
    there to exterminate the ogres.\n
    Old woman: If you are going far, you will be hungry. Take this with you.
    {'-' * 75}\n""")
    
    input(prompt ="""press < ENTER > to continue.\n""")
        
    # creating a quiz
    while True:
        try:
            quiz_2 = int(input(prompt = """
            What does the old woman give to Momotro?\n
            **Please input 1, 2, or 3.\n
            1. Dango:Dumpling
            2. Yokan:Azuki-bean jelly
            3. Manju:Sweet bun
            """))
        
        except:
            print("""
 　　　     Non-numbers were entered. Please enter only numbers.
            """)
            continue
    
        # displaying the correct answer and explanation  using nested conditions
        if quiz_2 == 1:
            print("""
 　　　     You're correct!\n
            Dumplings are one of the Japanese sweets that have been familiar to the 
            Japanese people since ancient times. Dumplings are made by adding water
            to powdered rice or other grains to make a dough, which is then rolled
            into a ball and steamed. They are usually skewered and often flavored 
            with soy sauce, soybean paste and soybean flour.
            """)
            break
            
        
        elif quiz_2 == 2:
            print("""
            That's incorrect.The correct answer is 1,Dango:Dumpling.\n
            Yokan, which originally represented lamb, was brought to Japan in 
            ancient times by Zen monks studying in China as one of the small meals
            eaten between meals. Since Zen monks were forbidden to eat meat, it is
            believed that the dish was made to resemble lamb by using plant based 
            ingredients such as azuki beans, wheat flour, and kuzu flour.
            """)
            break
            
        
        elif quiz_2 == 3:
            print("""
            That's incorrect.The correct answer is 1,Dango:Dumpling.\n
            Manju is a steamed sweet made by wrapping a sweetened azuki bean paste
            in a flour skin. The history of steamed buns is long, and
            it is said to have originated when Zhuge Liang, a Chinese military 
            strategist well known in the "Three Kingdoms," kneaded flour and 
            offered it to calm a flooding river. At that time, buns were steamed 
            meat buns with lamb and pork meat, but the Chinese monk who introduced
            buns to Japan was a monk who was not allowed to eat meat, so instead 
            of meat, he cooked red beans to make a sweet red bean paste, and 
            invented a bun wrapped in a flour skin.
            """)
            break
            
        
        # setting a different error message    
        else:
            print("""Invalid entry""")
            break
        
    input(prompt = """press < ENTER > to go to room_3.\n""")
    
    # This moves us into room_3 
    room_3() 
    
#########################################################
# Stage 3: Meeting with friends
######################################################### 

def room_3():
    
    #Printing introduction information
    print(f"""
    {'-' * 75}
    You're in room_3!\n
    Momotaro set off for Onigashima Island with a kibidango dumpling made by 
    the old woman hanging from his waist, and he met a dog on the way.\n
    Dog:Where are you going?
    Momotaro:I'm going to Onigashima to exterminate demons.
    Dog:What are the things you put down on your waist?
    Momotaro:These are Dango.
    Dog:If you give one of them to me, I'm gonna follow you.
    {'-' * 75}\n""")
    
    # Asking a user to input the answer
    quiz_3 = input(prompt = """
    Do you give dango to the dog? y/n
    """)
    
    if 'y' in quiz_3.lower():
        print("""Congrats!!You met one of your friends to fight together.\n""")
    elif 'n' in quiz_3.lower():
        fail()
    else:
        print("""Invalid entry""")
        
    input(prompt = """press < ENTER > to continue.\n""")
    
    #Printing the necessary information
    print(f"""
    {'-' * 75}
    Two friends are still hiding besides the dog, so let's find them.
    {'-' * 75}\n""")
    
    # Instantiating a list
    import random
    list_1 = ["b", "i", "r","d"]
    
    # Randominizing the list
    random.shuffle(list_1)
    print(list_1)
    quiz_4 = input(prompt = """
    Rearrange the letters of the alphabet in the correct order.
    """)
    
    if 'bird' or 'Bird' in quiz_4:
        print("""Congrats!!You met one of your friends to fight together.\n""")
    elif 'bird' or 'Bird' not in quiz_4:
        print("""That's incorrect.The correct answer is bird.\n""")
    else:
        print("""Invalid entry""")
        
    input(prompt = """press < ENTER > to go to continue.\n""")
    
    # Instantiating a list
    list_2 = ["m", "o", "n","k", "e","y"]
    
    # Randominizing the list
    random.shuffle(list_2)
    print(list_2)
    quiz_5 = input(prompt = """
    Rearrange the letters of the alphabet in the correct order.
    """)   
    
    if 'monkey' or 'Monkey' in quiz_5:
        print("""Congrats!!You met one of your friends to fight together.\n""")
    elif 'monkey' or 'Monkey' not in quiz_5:
        print("""That's incorrect.The correct answer is monkey.\n""")
    else:
        print("""Invalid entry""")
        
    input(prompt = """Press < ENTER > to go to room_4.\n""")
    
    # This moves us into room_4
    room_4() 
    
#########################################################
# Stage 4: Fighting with Demons
######################################################### 

def room_4():
    
    #Printing introduction information
    print(f"""
    {'-' * 75}
    You're in room_4!\n
    Momotaro, with his fellow dogs, monkeys, and birds, finally arrived at an
    island called Onigashima. Are you ready to fight with demons?
    {'-' * 75}\n""")
    
    import time 

    count = 4 

    #Countdown until 1
    while count>1:
        count -= 1
        print(count)
        time.sleep(1)
        
    input(prompt = """press < ENTER > to go to continue.\n""")
    
    import random

    # create a dictionary of quiz questions and answers
    quiz_dict = {
    "What is the English word for the Japanese word, 'Oni'?": "demon",
    "What is the English word for the Japanese word, 'Inu'?": "dog",
    "What is the English word for the Japanese word, 'Tori'?": "bird"
     }

    # randomly select a quiz question from the dictionary
    question = random.choice(list(quiz_dict.keys()))

    # display the question to the user
    print(question)

    # get the user's answer
    answer = input(prompt = "Enter your answer in lower case: ")

    # check if the answer is correct
    if answer.lower() == quiz_dict[question]:
        print("Correct!")
        win()
    else:
    # display a hint and give the user another chance to answer
        if question == "What is the English word for the Japanese word, 'Oni'?":
            print("Hint: an evil spirit or devil")
        elif question == "What is the English word for the Japanese word, 'Tori'?":
            print("Hint: animals that can fly")
        else:
            print("Hint: some people like cat, but other people like...")

        # ask the user for another answer
        answer = input(prompt = "Enter another answer in lower case: ")

        # check if the second answer is correct
        if answer.lower() == quiz_dict[question]:
            print("Correct!")
            win()
        else:
            print("Sorry, you are out of guess. The correct answer is:", quiz_dict[question])
            fail()
        
#Displaying ascii art  
def win():
    tprint("win",font = "block")

#Force quitting the game
def fail():
    print("""You've failed, but thanks for playing!\n""")
    input(prompt = """Press any key to exit.\n""")

room_0()
# Out:
#     ---------------------------------------------------------------------------
#      STORY
#      Momotaro is an old Japanese fairy tale. Momotaro, the hero, is born from
#      a peach and goes to exterminate ogres. Will he be able to exterminate the
#      ogres and bring peace to his village?
#
#
#      DIRECTIONS
#      In this game, you are going to answer some quizzes to help "Momotaro".
#      Please read the instruction for each question carefully.
#     ---------------------------------------------------------------------------
#      START
#      Once upon a time, there was an old man and an old woman.
#      The grandfather went to the mountains to cut bush bushes, and the
#      grandmother went to the river to wash clothes.While the grandmother
#      was washing her clothes in the river, a big peach came floating down
#      from upstream.
#     ---------------------------------------------------------------------------
#
#
#     Do you wanna pick the peach? y/n
# ...
